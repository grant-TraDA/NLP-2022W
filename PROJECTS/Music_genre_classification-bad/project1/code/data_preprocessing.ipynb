# %%
import os
import pandas as pd
import sklearn.model_selection as ms

import re
from joblib import Parallel, delayed
import contractions
import nltk
from nltk.tokenize import word_tokenize  
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from imblearn.under_sampling import RandomUnderSampler

# %%
min_obs = 5000

# %%
if not os.path.exists('data/train'):
    os.makedirs('data/train')
if not os.path.exists('data/val'):
    os.makedirs('data/val')
if not os.path.exists('data/test'):
    os.makedirs('data/test')

# %%
# we are deleting special strings ("verse", "chorus", "2x" etc.), 
# strings in brackets and numbers
delete_str = ['"', ',', 
              'VERSE', 'Verse', 'verse', 
              'CHORUS', 'Chorus', 'chorus',
              '\[.*\]', r'\dx', r'\d+'
             ]

def basic_process(text):
    # deleting above strings
    for ds in delete_str:
        text = re.sub(ds, '', text)
    # deleting new line
    text = re.sub('\n', ' ', text)
    # expanding contractions
    expanded_words = [] 
    for word in text.split():
        expanded_words.append(contractions.fix(word))  
    text = ' '.join(expanded_words)
    # deleting all special characters
    text = ''.join(c for c in text if c.isalnum() or c == " ")
    # removing repeated spaces
    text = re.sub(' +', ' ', text)
    # lowering text
    text = text.lower()
    return text

# %%
def nltk_process(text):
    nltk_stop_words = set(stopwords.words("english"))
    lemmatizer = WordNetLemmatizer()
    # tokenization
    tokens = word_tokenize(text)
    result = []
    for word in tokens:
        # deleting stop words
        if word not in nltk_stop_words:
            # lemmatization
            lemma = lemmatizer.lemmatize(word)
            result.append(lemma)
    return result

# %%
# # Unused spacy version: (it deletes much more words as stopwords than nltk)
# pip install spacy
# python -m spacy downloady en
# import spacy
# nlp = spacy.load('en_core_web_sm')
# def spacy_process(text):
#     # tokenization
#     doc = nlp(text)
#     result = []
#     for token in doc:
#         # lemmatization
#         lemma = token.lemma_
#         # deleting stop words
#         lexeme = nlp.vocab[lemma]
#         if lexeme.is_stop == False:
#             result.append(lemma.lower())
#     return result

# %%
def process_lyrics_basic(lyrics):
    return Parallel(n_jobs=-1, backend='threading')(delayed(basic_process)(text) for text in lyrics)
# nltk doesn't work with Parallel in contradiciton to spacy
def process_lyrics(lyrics):
    return [nltk_process(text) for text in lyrics]

# %%
def split_and_save(df, name):
    df_train, df_test = ms.train_test_split(df, train_size=0.7, random_state=7, stratify=df.genre)
    df_train.to_csv(f'data/train/{name}.csv', index=False)
    dF_test.to_csv(f'data/test/{name}.csv', index=False)

# %% [markdown]
# # MetroLyrics
#
# source of data: https://github.com/hiteshyalamanchili/SongGenreClassification/blob/master/dataset/english_cleaned_lyrics.zip

# %%
d = pd.read_csv('data/raw/english_cleaned_lyrics.csv', index_col=0)

# %%
d = d[['genre', 'lyrics']]
d
# Out:
#           genre                                             lyrics
# 0           Pop  Oh baby how you doing You know I'm gonna cut r...
# 1           Pop  playin everything so easy it's like you seem s...
# 2           Pop  If you search For tenderness It isn't hard to ...
# 3           Pop  Oh oh oh I oh oh oh I If I wrote a book about ...
# 4           Pop  Party the people the people the party it's pop...
# ...         ...                                                ...
# 362232  Country  I gotta say Boy after only just a couple of da...
# 362233  Country  I helped you find her diamond ring You made me...
# 362234  Country  Look at the couple in the corner booth Looks a...
# 362235  Country  When I fly off this mortal earth And I'm measu...
# 362236  Country  I heard from a friend of a friend of a friend ...
#
# [218210 rows x 2 columns]

# %%
d = d[d.genre != "Other"]
d = d.replace("Folk", "Country")

# %%
vc = d.genre.value_counts()
vc
# Out:
# Rock          100053
# Pop            34137
# Hip-Hop        22654
# Metal          21210
# Country        15847
# Jazz            7310
# Electronic      6942
# R&B             3336
# Indie           2935
# Name: genre, dtype: int64

# %%
processed_lyrics = process_lyrics_basic(d.lyrics)
d['lyrics'] = processed_lyrics
d
# Out:
#           genre                                             lyrics
# 0           Pop  oh baby how you doing you know i am going to c...
# 1           Pop  playin everything so easy it is like you seem ...
# 2           Pop  if you search for tenderness it is not hard to...
# 3           Pop  oh oh oh i oh oh oh i if i wrote a book about ...
# 4           Pop  party the people the people the party it is po...
# ...         ...                                                ...
# 362232  Country  i got to say boy after only just a couple of d...
# 362233  Country  i helped you find her diamond ring you made me...
# 362234  Country  look at the couple in the corner booth looks a...
# 362235  Country  when i fly off this mortal earth and i am meas...
# 362236  Country  i heard from a friend of a friend of a friend ...
#
# [214424 rows x 2 columns]

# %%
split_and_save(d, "metrolyrics")

# %%
processed_lyrics = process_lyrics(d.lyrics)
d['tokens'] = processed_lyrics
d
# Out:
#           genre                                             lyrics  \
# 0           Pop  oh baby how you doing you know i am going to c...
# 1           Pop  playin everything so easy it is like you seem ...
# 2           Pop  if you search for tenderness it is not hard to...
# 3           Pop  oh oh oh i oh oh oh i if i wrote a book about ...
# 4           Pop  party the people the people the party it is po...
# ...         ...                                                ...
# 362232  Country  i got to say boy after only just a couple of d...
# 362233  Country  i helped you find her diamond ring you made me...
# 362234  Country  look at the couple in the corner booth looks a...
# 362235  Country  when i fly off this mortal earth and i am meas...
# 362236  Country  i heard from a friend of a friend of a friend ...
#
#                                                    tokens
# 0       [oh, baby, know, going, cut, right, chase, wom...
# 1       [playin, everything, easy, like, seem, sure, s...
# 2       [search, tenderness, hard, find, love, need, l...
# 3       [oh, oh, oh, oh, oh, oh, wrote, book, stand, t...
# 4       [party, people, people, party, popping, sittin...
# ...                                                   ...
# 362232  [got, say, boy, couple, date, hand, outright, ...
# 362233  [helped, find, diamond, ring, made, try, every...
# 362234  [look, couple, corner, booth, look, lot, like,...
# 362235  [fly, mortal, earth, measured, depth, girth, f...
# 362236  [heard, friend, friend, friend, finally, got, ...
#
# [214424 rows x 3 columns]

# %%
split_and_save(d, "metrolyrics_proc")

# %% [markdown]
# # Song lyrics from 79 musical genres
#
# source of data: https://www.kaggle.com/datasets/neisse/scrapped-lyrics-from-6-genres

# %%
d1 = pd.read_csv('data/raw/artists-data.csv')
d1
# Out:
#                    Artist                           Genres  Songs  Popularity  \
# 0           Ivete Sangalo              Pop; Axé; Romântico  313.0         4.4
# 1     Chiclete com Banana                              Axé  268.0         3.8
# 2               Banda Eva           Axé; Romântico; Reggae  215.0         2.3
# 3               É O Tchan                              Axé  129.0         1.6
# 4          Claudia Leitte              Pop; Axé; Romântico  167.0         1.5
# ...                   ...                              ...    ...         ...
# 4163        Miriam Makeba  World Music; Black Music; Blues   17.0         0.0
# 4164      Freddie Aguilar                      World Music   61.0         0.0
# 4165      Amadou & Mariam                      World Music   14.0         0.0
# 4166         Magic System    World Music; Gospel/Religioso   16.0         0.0
# 4167         Johnny Clegg    World Music; Gospel/Religioso   34.0         0.0
#
#                        Link
# 0           /ivete-sangalo/
# 1     /chiclete-com-banana/
# 2               /banda-eva/
# 3               /e-o-tchan/
# 4          /claudia-leitte/
# ...                     ...
# 4163        /miriam-makeba/
# 4164      /freddie-aguilar/
# 4165        /amadou-mariam/
# 4166         /magic-system/
# 4167         /clegg-johnny/
#
# [4168 rows x 5 columns]

# %%
d1.Genres = d1.Genres.str.replace(',', ';')
d1.Genres = d1.Genres.str.split(r'\s*;\s*').str[0]
d1
# Out:
#                    Artist       Genres  Songs  Popularity  \
# 0           Ivete Sangalo          Pop  313.0         4.4
# 1     Chiclete com Banana          Axé  268.0         3.8
# 2               Banda Eva          Axé  215.0         2.3
# 3               É O Tchan          Axé  129.0         1.6
# 4          Claudia Leitte          Pop  167.0         1.5
# ...                   ...          ...    ...         ...
# 4163        Miriam Makeba  World Music   17.0         0.0
# 4164      Freddie Aguilar  World Music   61.0         0.0
# 4165      Amadou & Mariam  World Music   14.0         0.0
# 4166         Magic System  World Music   16.0         0.0
# 4167         Johnny Clegg  World Music   34.0         0.0
#
#                        Link
# 0           /ivete-sangalo/
# 1     /chiclete-com-banana/
# 2               /banda-eva/
# 3               /e-o-tchan/
# 4          /claudia-leitte/
# ...                     ...
# 4163        /miriam-makeba/
# 4164      /freddie-aguilar/
# 4165        /amadou-mariam/
# 4166         /magic-system/
# 4167         /clegg-johnny/
#
# [4168 rows x 5 columns]

# %%
d1 = d1[['Genres', 'Link']]
d1
# Out:
#            Genres                   Link
# 0             Pop        /ivete-sangalo/
# 1             Axé  /chiclete-com-banana/
# 2             Axé            /banda-eva/
# 3             Axé            /e-o-tchan/
# 4             Pop       /claudia-leitte/
# ...           ...                    ...
# 4163  World Music        /miriam-makeba/
# 4164  World Music      /freddie-aguilar/
# 4165  World Music        /amadou-mariam/
# 4166  World Music         /magic-system/
# 4167  World Music         /clegg-johnny/
#
# [4168 rows x 2 columns]

# %%
d1.Genres.value_counts()
# Out:
# Gospel/Religioso    464
# Rock                246
# Pop                 236
# Sertanejo           220
# Indie               175
#                    ...
# Metal                 2
# Lo-fi                 2
# Electro Swing         2
# Piseiro               1
# Urban                 1
# Name: Genres, Length: 79, dtype: int64

# %%
d2 = pd.read_csv('data/raw/lyrics-data.csv')
d2
# Out:
#                   ALink                                          SName  \
# 0       /ivete-sangalo/                                          Arerê
# 1       /ivete-sangalo/                Se Eu Não Te Amasse Tanto Assim
# 2       /ivete-sangalo/                                    Céu da Boca
# 3       /ivete-sangalo/                          Quando A Chuva Passar
# 4       /ivete-sangalo/                                   Sorte Grande
# ...                 ...                                            ...
# 379926   /clegg-johnny/                                    The Waiting
# 379927   /clegg-johnny/                          Too Early For The Sky
# 379928   /clegg-johnny/  Warsaw 1943 (I Never Betrayed The Revolution)
# 379929   /clegg-johnny/                     When The System Has Fallen
# 379930   /clegg-johnny/                            Woman Be My Country
#
#                                                     SLink  \
# 0                               /ivete-sangalo/arere.html
# 1       /ivete-sangalo/se-eu-nao-te-amasse-tanto-assim...
# 2                          /ivete-sangalo/chupa-toda.html
# 3               /ivete-sangalo/quando-a-chuva-passar.html
# 4                        /ivete-sangalo/sorte-grande.html
# ...                                                   ...
# 379926                     /clegg-johnny/the-waiting.html
# 379927           /clegg-johnny/too-early-for-the-sky.html
# 379928  /clegg-johnny/warsaw-1943-i-never-betrayed-the...
# 379929      /clegg-johnny/when-the-system-has-fallen.html
# 379930             /clegg-johnny/woman-be-my-country.html
#
#                                                     Lyric language
# 0       Tudo o que eu quero nessa vida,\nToda vida, é\...       pt
# 1       Meu coração\nSem direção\nVoando só por voar\n...       pt
# 2       É de babaixá!\nÉ de balacubaca!\nÉ de babaixá!...       pt
# 3       Quando a chuva passar\n\nPra quê falar\nSe voc...       pt
# 4       A minha sorte grande foi você cair do céu\nMin...       pt
# ...                                                   ...      ...
# 379926  Chorus\nHere we stand waiting on the plain\nDa...       en
# 379927  I nearly disappeared into the mouth of a croco...       en
# 379928  Amambuka, amambuka azothengisa izwe lakithi, i...       en
# 379929  Sweat in the heat for days on end\nwaiting for...       en
# 379930  Here we stand on the edge of the day\nFaces me...       en
#
# [379931 rows x 5 columns]

# %%
d2 = d2[d2.language == 'en']
d2
# Out:
#                   ALink                                              SName  \
# 69      /ivete-sangalo/                                   Careless Whisper
# 86      /ivete-sangalo/  Could You Be Loved / Citação Musical do Rap: S...
# 88      /ivete-sangalo/                             Cruisin' (Part. Saulo)
# 111     /ivete-sangalo/                                               Easy
# 140     /ivete-sangalo/                  For Your Babies (The Voice cover)
# ...                 ...                                                ...
# 379926   /clegg-johnny/                                        The Waiting
# 379927   /clegg-johnny/                              Too Early For The Sky
# 379928   /clegg-johnny/      Warsaw 1943 (I Never Betrayed The Revolution)
# 379929   /clegg-johnny/                         When The System Has Fallen
# 379930   /clegg-johnny/                                Woman Be My Country
#
#                                                     SLink  \
# 69                   /ivete-sangalo/careless-whisper.html
# 86      /ivete-sangalo/could-you-be-loved-citacao-musi...
# 88                 /ivete-sangalo/cruisin-part-saulo.html
# 111                              /ivete-sangalo/easy.html
# 140     /ivete-sangalo/for-your-babies-the-voice-cover...
# ...                                                   ...
# 379926                     /clegg-johnny/the-waiting.html
# 379927           /clegg-johnny/too-early-for-the-sky.html
# 379928  /clegg-johnny/warsaw-1943-i-never-betrayed-the...
# 379929      /clegg-johnny/when-the-system-has-fallen.html
# 379930             /clegg-johnny/woman-be-my-country.html
#
#                                                     Lyric language
# 69      I feel so unsure\nAs I take your hand and lead...       en
# 86      Don't let them fool, ya\nOr even try to school...       en
# 88      Baby, let's cruise, away from here\nDon't be c...       en
# 111     Know it sounds funny\nBut, I just can't stand ...       en
# 140     You've got that look again\nThe one I hoped I ...       en
# ...                                                   ...      ...
# 379926  Chorus\nHere we stand waiting on the plain\nDa...       en
# 379927  I nearly disappeared into the mouth of a croco...       en
# 379928  Amambuka, amambuka azothengisa izwe lakithi, i...       en
# 379929  Sweat in the heat for days on end\nwaiting for...       en
# 379930  Here we stand on the edge of the day\nFaces me...       en
#
# [191814 rows x 5 columns]

# %%
d2 = d2[['ALink', 'Lyric']]
d2 = d2.rename(columns={'ALink': 'Link'})
d2
# Out:
#                    Link                                              Lyric
# 69      /ivete-sangalo/  I feel so unsure\nAs I take your hand and lead...
# 86      /ivete-sangalo/  Don't let them fool, ya\nOr even try to school...
# 88      /ivete-sangalo/  Baby, let's cruise, away from here\nDon't be c...
# 111     /ivete-sangalo/  Know it sounds funny\nBut, I just can't stand ...
# 140     /ivete-sangalo/  You've got that look again\nThe one I hoped I ...
# ...                 ...                                                ...
# 379926   /clegg-johnny/  Chorus\nHere we stand waiting on the plain\nDa...
# 379927   /clegg-johnny/  I nearly disappeared into the mouth of a croco...
# 379928   /clegg-johnny/  Amambuka, amambuka azothengisa izwe lakithi, i...
# 379929   /clegg-johnny/  Sweat in the heat for days on end\nwaiting for...
# 379930   /clegg-johnny/  Here we stand on the edge of the day\nFaces me...
#
# [191814 rows x 2 columns]

# %%
d3 = pd.merge(d1, d2, on='Link')
d3 = d3[['Genres', 'Lyric']]
d3 = d3.rename(columns={'Genres': 'genre', 'Lyric': 'lyrics'})

# %%
processed_lyrics = process_lyrics_basic(d3.lyrics)
d3['lyrics'] = processed_lyrics
d3
# Out:
#               genre                                             lyrics
# 0               Pop  i feel so unsure as i take your hand and lead ...
# 1               Pop  do not let them fool ya or even try to school ...
# 2               Pop  baby let us cruise away from here do not be co...
# 3               Pop  know it sounds funny but i just cannot stand t...
# 4               Pop  you have got that look again the one i hoped i...
# ...             ...                                                ...
# 191382  World Music  here we stand waiting on the plain darkness ha...
# 191383  World Music  i nearly disappeared into the mouth of a croco...
# 191384  World Music  amambuka amambuka azothengisa izwe lakithi izw...
# 191385  World Music  sweat in the heat for days on end waiting for ...
# 191386  World Music  here we stand on the edge of the day faces mel...
#
# [191387 rows x 2 columns]

# %%
vc = d3.genre.value_counts()
vc
# Out:
# Rock             25177
# Pop              13759
# Heavy Metal      13496
# Indie            12998
# Rap               9589
#                  ...
# Electro Swing        6
# Jovem Guarda         6
# Forró                3
# Lo-fi                1
# Regional             1
# Name: genre, Length: 73, dtype: int64

# %%
vc[vc < min_obs]
# Out:
# Hard Rock        4632
# Soul Music       4518
# Dance            4252
# Punk Rock        4157
# Folk             4055
#                  ...
# Electro Swing       6
# Jovem Guarda        6
# Forró               3
# Lo-fi               1
# Regional            1
# Name: genre, Length: 62, dtype: int64

# %%
d3 = d3[d3.genre.isin(vc[vc >= min_obs].index.tolist())]
d3 = d3[d3.genre != "Pop/Rock"]
d3 = d3.replace("Heavy Metal", "Metal")
d3 = d3.replace("Rock Alternativo", "Alternative Rock")

# %%
vc = d3.genre.value_counts()
vc
# Out:
# Rock                25177
# Pop                 13759
# Metal               13496
# Indie               12998
# Rap                  9589
# Hip Hop              8412
# Country              7377
# Alternative Rock     5555
# R&B                  5309
# Gospel/Religioso     5017
# Name: genre, dtype: int64

# %%
split_and_save(d3, "musicalgenres")

# %%
processed_lyrics = process_lyrics(d3.lyrics)
d3['tokens'] = processed_lyrics
d3
# Out:
#                    genre                                             lyrics  \
# 0                    Pop  i feel so unsure as i take your hand and lead ...
# 1                    Pop  do not let them fool ya or even try to school ...
# 2                    Pop  baby let us cruise away from here do not be co...
# 3                    Pop  know it sounds funny but i just cannot stand t...
# 4                    Pop  you have got that look again the one i hoped i...
# ...                  ...                                                ...
# 182627  Alternative Rock  words guitar i got it words guitar i like it w...
# 182628  Alternative Rock  i got your letter today i read the things you ...
# 182629  Alternative Rock  you are not it you are not it you are the hott...
# 182630  Alternative Rock  you are no rock n roll fun like a party that i...
# 182631  Alternative Rock  acid tooth it is got nothing to do with you bu...
#
#                                                    tokens
# 0       [feel, unsure, take, hand, lead, dance, floor,...
# 1       [let, fool, ya, even, try, school, ya, oh, got...
# 2       [baby, let, u, cruise, away, confused, way, cl...
# 3       [know, sound, funny, stand, pain, girl, leavin...
# 4       [got, look, one, hoped, lad, face, beaming, sm...
# ...                                                   ...
# 182627  [word, guitar, got, word, guitar, like, way, w...
# 182628  [got, letter, today, read, thing, say, thing, ...
# 182629  [hottest, band, around, biggest, dick, town, m...
# 182630  [rock, n, roll, fun, like, party, begun, walk,...
# 182631  [acid, tooth, got, nothing, want, watch, chew,...
#
# [106689 rows x 3 columns]

# %%
split_and_save(d3, "musicalgenres_proc")

# %%
d4 = pd.concat([d, d3])
d4
# Out:
#                    genre                                             lyrics  \
# 0                    Pop  oh baby how you doing you know i am going to c...
# 1                    Pop  playin everything so easy it is like you seem ...
# 2                    Pop  if you search for tenderness it is not hard to...
# 3                    Pop  oh oh oh i oh oh oh i if i wrote a book about ...
# 4                    Pop  party the people the people the party it is po...
# ...                  ...                                                ...
# 182627  Alternative Rock  words guitar i got it words guitar i like it w...
# 182628  Alternative Rock  i got your letter today i read the things you ...
# 182629  Alternative Rock  you are not it you are not it you are the hott...
# 182630  Alternative Rock  you are no rock n roll fun like a party that i...
# 182631  Alternative Rock  acid tooth it is got nothing to do with you bu...
#
#                                                    tokens
# 0       [oh, baby, know, going, cut, right, chase, wom...
# 1       [playin, everything, easy, like, seem, sure, s...
# 2       [search, tenderness, hard, find, love, need, l...
# 3       [oh, oh, oh, oh, oh, oh, wrote, book, stand, t...
# 4       [party, people, people, party, popping, sittin...
# ...                                                   ...
# 182627  [word, guitar, got, word, guitar, like, way, w...
# 182628  [got, letter, today, read, thing, say, thing, ...
# 182629  [hottest, band, around, biggest, dick, town, m...
# 182630  [rock, n, roll, fun, like, party, begun, walk,...
# 182631  [acid, tooth, got, nothing, want, watch, chew,...
#
# [321113 rows x 3 columns]

# %%
vc = d4.genre.value_counts()
vc
# Out:
# Rock                125230
# Pop                  47896
# Metal                34706
# Country              23224
# Hip-Hop              22654
# Indie                15933
# Rap                   9589
# R&B                   8645
# Hip Hop               8412
# Jazz                  7310
# Electronic            6942
# Alternative Rock      5555
# Gospel/Religioso      5017
# Name: genre, dtype: int64

# %%
split_and_save(d4, "full")

# %%
d4 = d4[d4.genre.isin(vc[vc >= 20000].index.tolist())]

# %%
vc = d4.genre.value_counts()
vc
# Out:
# Rock       125230
# Pop         47896
# Metal       34706
# Country     23224
# Hip-Hop     22654
# Name: genre, dtype: int64

# %%
split_and_save(d4, "small")

# %%
X = d4[["lyrics","tokens"]]
y = d4.genre

# %%
under_sampler = RandomUnderSampler(random_state=7)
d5, y_res = under_sampler.fit_resample(X, y)

# %%
d5['genre'] = y_res

# %%
d5
# Out:
#                                                    lyrics  \
# 0       one sages have come from far following one bri...
# 1       you will remember me when the west winds moves...
# 2       one day the train was passing i caught it comi...
# 3       it is been a long long time writers sammy cahn...
# 4       shortcut to part of bill monroe lyrics bill mo...
# ...                                                   ...
# 113265  sanctify me clean out my closet take away anyt...
# 113266  stare out my window until the light fades the ...
# 113267  oh heartbeat city here we come and happy days ...
# 113268  what would we do if love were dead what would ...
# 113269  a time warp scene a cy fi story a dirt coloure...
#
#                                                    tokens    genre
# 0       [one, sage, come, far, following, one, bright,...  Country
# 1       [remember, west, wind, move, among, field, bar...  Country
# 2       [one, day, train, passing, caught, comin, look...  Country
# 3       [long, long, time, writer, sammy, cahn, jule, ...  Country
# 4       [shortcut, part, bill, monroe, lyric, bill, mo...  Country
# ...                                                   ...      ...
# 113265  [sanctify, clean, closet, take, away, anything...     Rock
# 113266  [stare, window, light, fade, darkness, overcom...     Rock
# 113267  [oh, heartbeat, city, come, happy, day, count,...     Rock
# 113268  [would, love, dead, would, say, silly, thing, ...     Rock
# 113269  [time, warp, scene, cy, fi, story, dirt, colou...     Rock
#
# [113270 rows x 3 columns]

# %%
vc = d5.genre.value_counts()
vc
# Out:
# Country    22654
# Hip-Hop    22654
# Metal      22654
# Pop        22654
# Rock       22654
# Name: genre, dtype: int64

# %%
split_and_save(d5, "small_balanced")
