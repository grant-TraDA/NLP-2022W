# %%
import pandas as pd
import json
import openai
from ast import literal_eval
from tqdm import tqdm

# %%
data = pd.read_csv("../dataset/recipes_w_search_terms.csv")
with open("../openai_key.txt") as f:
    key = f.readline()
openai.api_key = key
MODEL_TO_USE = "text-davinci-003"

# %%
data.ingredients = data.ingredients.apply(lambda x: "\n".join(literal_eval(x)))

# %%
with open("../prompts_templates.json") as f:
    prompt = json.load(f)["dietary_tags_classification"][0]

# %%
model_inputs = [
    prompt.replace("INPUT_TEXT", text) for text in data.ingredients[:50]
]

# %%
responses = []
number_of_concurrent_responses = 2
for i in tqdm(range(len(model_inputs) // number_of_concurrent_responses)):
    response = openai.Completion.create(
        model=MODEL_TO_USE,
        prompt=model_inputs[
            i
            * number_of_concurrent_responses : (i + 1)
            * number_of_concurrent_responses
        ],
        temperature=0,
        max_tokens=1024,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0,
    )
    responses += [json.loads(x["text"]) for x in response["choices"]]
if len(model_inputs) % number_of_concurrent_responses != 0:
    response = openai.Completion.create(
        model=MODEL_TO_USE,
        prompt=model_inputs[(i + 1) * number_of_concurrent_responses :],
        temperature=0,
        max_tokens=1024,
        top_p=1.0,
        frequency_penalty=0.0,
        presence_penalty=0.0,
    )
    responses += [json.loads(x["text"]) for x in response["choices"]]
# Out:
# 100%|██████████| 25/25 [01:18<00:00,  3.15s/it]

# %%
responses
# Out:
# [{'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Low-Carb': False,
#   'Low-Fat': False,
#   'Keto': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegan': True,
#   'Vegetarian': True,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Low-Carb': False,
#   'Low-Fat': False,
#   'Keto': False},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True},
#  {'vegetarian': False,
#   'vegan': False,
#   'gluten_free': False,
#   'dairy_free': True,
#   'nut_free': True},
#  {'Vegan': True,
#   'Vegetarian': True,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': False,
#   'Soy-Free': True,
#   'Low-Carb': False,
#   'Low-Sugar': False},
#  {'vegetarian': False,
#   'vegan': False,
#   'gluten_free': True,
#   'dairy_free': False,
#   'nut_free': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Nut-Free': True},
#  {'Vegetarian': ['onion',
#    'garlic',
#    'potatoes',
#    'flour',
#    'milk',
#    'black pepper',
#    'nutmeg',
#    'creamed corn',
#    'parsley'],
#   'Low Sodium': ['low sodium chicken broth'],
#   'Seafood': ['lump crabmeat'],
#   'Spicy': ['cayenne pepper'],
#   'Dairy': ['butter', 'milk', 'creamed corn']},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Sugar-Free': False},
#  {'Gluten-Free': False,
#   'Vegan': False,
#   'Vegetarian': True,
#   'Keto': False,
#   'Paleo': False,
#   'Low-Carb': False,
#   'Low-Fat': False,
#   'Sugar-Free': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Nut-Free': True,
#   'Soy-Free': True,
#   'Keto': False,
#   'Low-Carb': False,
#   'Paleo': False},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Low-Fat': True,
#   'Low-Carb': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Nut-Free': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Nut-Free': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Low-Sodium': True,
#   'Low-Fat': False,
#   'Paleo': False,
#   'Keto': False},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Kosher': True,
#   'Paleo': False,
#   'Low-Carb': True,
#   'Low-Sodium': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Nut-Free': True,
#   'Soy-Free': True},
#  {'Vegetarian': True,
#   'Vegan': True,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Low-Carb': False,
#   'Low-Fat': False,
#   'Paleo': False,
#   'Keto': False},
#  {'Vegan': True,
#   'Vegetarian': True,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True,
#   'Soy-Free': True},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Kosher': True},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Keto': False,
#   'Paleo': False},
#  {'dairy': ['heavy cream', 'butter'],
#   'eggs': ['eggs', 'egg yolks'],
#   'sugar': ['sugar', 'dark brown sugar', 'brown sugar'],
#   'fruits': ['fresh raspberry', 'bananas'],
#   'nuts': ['pecans', 'pralines'],
#   'coffee': ['coffee beans'],
#   'alcohol': ['brandy'],
#   'baking': ['baking chocolate', 'vanilla bean']},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True},
#  {'Gluten-Free': False,
#   'Vegan': False,
#   'Vegetarian': True,
#   'Dairy-Free': False,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegetarian': True,
#   'Gluten-Free': False,
#   'Dairy-Free': True,
#   'Nut-Free': False,
#   'Soy-Free': True,
#   'Keto': False,
#   'Low-Carb': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Kosher': True,
#   'Halal': False},
#  {'unsalted butter': 'dairy',
#   'sugar': 'refined sugar',
#   'all-purpose flour': 'gluten',
#   'baking soda': 'sodium',
#   'salt': 'sodium',
#   'eggs': 'animal protein',
#   'walnuts': 'nuts',
#   'vanilla': 'flavoring',
#   'red food coloring': 'artificial coloring',
#   'blue food coloring': 'artificial coloring',
#   'icing sugar': 'refined sugar'},
#  {'vegetarian': False,
#   'vegan': False,
#   'gluten_free': True,
#   'dairy_free': False,
#   'nut_free': True},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Kosher': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Nut-Free': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Sugar-Free': False},
#  {'Vegan': False,
#   'Vegetarian': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Nut-Free': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Kosher': True,
#   'Paleo': False,
#   'Low-Carb': False},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegetarian': True,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Nut-Free': True},
#  {'Vegan': False,
#   'Vegetarian': True,
#   'Gluten-Free': False,
#   'Dairy-Free': True,
#   'Sugar-Free': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Low-Carb': True,
#   'Low-Fat': True,
#   'Paleo': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': False,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegan': False,
#   'Vegetarian': True,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True,
#   'Soy-Free': True},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Nut-Free': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': False,
#   'Dairy-Free': False,
#   'Sugar-Free': False,
#   'Low-Carb': False,
#   'Keto': False,
#   'Paleo': False},
#  {'Vegetarian': False,
#   'Vegan': False,
#   'Gluten-Free': True,
#   'Dairy-Free': True,
#   'Nut-Free': True}]

# %%
results_dataframe = pd.DataFrame(
    {
        "ingredients_list": data.ingredients[: len(responses)].tolist(),
        "gpt-3_classification": responses,
    }
)

# %%
results_dataframe.to_csv(
    "multioutput_dietary_tags_classification_results.csv", index=False
)
